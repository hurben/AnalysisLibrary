# %%
data <- rnorm(n=20, mean = 10, sd = 2)
data2 <- rnorm(n=20, mean = 11, sd =1)

# %%
data
data2
# Out:
#  [1]  9.096682 14.955672 12.366016  9.124126 13.566401 11.200687  5.280072
#  [8] 10.712659  7.927586  9.187213 10.952751  6.555447 10.865541  8.323542
# [15]  9.137224 10.271164 11.266520 11.131400 10.739545  6.597998
#  [1] 12.078439 12.392074 11.583870 11.310927 10.366302 13.323897 11.382919
#  [8] 11.260185 11.148152 11.017816  9.644351 12.030465 11.720947  9.746077
# [15]  9.455981 11.045146 13.669325 10.615608 11.464577 10.593067

# %%
h0 <- 10

# %%
t.test(data, mu = h0)
t.test(data, y = data2)
# Out:
# 	One Sample t-test
#
# data:  data
# t = -0.070298, df = 19, p-value = 0.9447
# alternative hypothesis: true mean is not equal to 10
# 95 percent confidence interval:
#   8.858675 11.067149
# sample estimates:
# mean of x
#  9.962912
# 	Welch Two Sample t-test
#
# data:  data and data2
# t = -2.2849, df = 26.858, p-value = 0.03044
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -2.523833 -0.135355
# sample estimates:
# mean of x mean of y
#  9.962912 11.292506
