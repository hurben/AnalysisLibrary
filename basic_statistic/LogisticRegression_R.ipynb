# %%
#Logisticn
library(datasets)
library(ggplot2)

iris_dataframe <- data.frame(iris)

# %%
colnames(iris_dataframe)
iris_sepal <- iris_dataframe[,1]
length(iris_sepal)
iris_label <- iris_dataframe[,5]

#150samples
# Out:
# [1] "Sepal.Length" "Sepal.Width"  "Petal.Length" "Petal.Width"  "Species"
# [1] 150

# %%
iris_dataframe <- subset(iris_dataframe, Species == "setosa" | Species == "versicolor")
length(iris_sepal)

iris_sepal <- iris_dataframe[,1]
iris_label <- iris_dataframe[,5]

analysis_ready_data <- data.frame(iris_sepal, iris_label)

#excluding 1 label, leaving 100samples
# Out:
# [1] 100

# %%
m <- glm(iris_label ~ ., data = analysis_read_data, family = binomial)

# %%
m
# Out:
# Call:  glm(formula = iris_label ~ ., family = binomial, data = analysis_read_data)
#
# Coefficients:
# (Intercept)   iris_sepal
#      -27.83         5.14
#
# Degrees of Freedom: 99 Total (i.e. Null);  98 Residual
# Null Deviance:	    138.6
# Residual Deviance: 64.21 	AIC: 68.21

# %%
plot_dat <- data.frame(sepal = iris_sepal, label = iris_label)
ggplot(plot_dat, aes(x = sepal, fill = label)) + geom_dotplot(alpha = 0.5)
# Out:
# `stat_bindot()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
